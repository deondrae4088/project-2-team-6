# %% [markdown]
# # DATA CLEANING AND PREPROCESSING

# %% [markdown]
# **Data Source** : Federal Reserve Economic data

# %% [markdown]
# **Importing the necessary libraries**

# %%
# import pandas  library and make it as pd
import pandas as pd
# import numpy library and make it as np
import numpy as np
# import matplotlib.pyplot  and make it as plt its is used for visuvalization
import matplotlib.pyplot as plt
# import seaborn library and make it as sns
import seaborn as sns
from warnings import filterwarnings
filterwarnings("ignore")

# %%
_2017_2024 = pd.read_csv("/content/data-2017-2024CA.csv")
_2017_2024.head()
# Out:
#          date  Monthly payment on a 2 bedroom house  \
# 0  2017-01-01                           2205.609033
# 1  2017-02-01                           2244.785113
# 2  2017-03-01                           2290.331296
# 3  2017-04-01                           2293.783598
# 4  2017-05-01                           2311.241450
#
#    Monthly rent on typical property
# 0                       1822.635793
# 1                       1834.327022
# 2                       1848.212552
# 3                       1858.508820
# 4                       1868.118135

# %% [markdown]
# **Load the data into pandas dataframe**

# %%
index=pd.read_csv("/content/data-2017-2024CA.csv",index_col=['date'])
index.rename(columns={'date':'DATE'},inplace=True)
index.head()
# Out:
#             Monthly payment on a 2 bedroom house  \
# date
# 2017-01-01                           2205.609033
# 2017-02-01                           2244.785113
# 2017-03-01                           2290.331296
# 2017-04-01                           2293.783598
# 2017-05-01                           2311.241450
#
#             Monthly rent on typical property
# date
# 2017-01-01                       1822.635793
# 2017-02-01                       1834.327022
# 2017-03-01                       1848.212552
# 2017-04-01                       1858.508820
# 2017-05-01                       1868.118135

# %%
index.shape
# Out:
# (96, 2)

# %%
index.count()
# Out:
# Monthly payment on a 2 bedroom house    96
# Monthly rent on typical property        92
# dtype: int64

# %%
index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96 entries, 2017-01-01 to 2024-12-01
# Data columns (total 2 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Monthly payment on a 2 bedroom house  96 non-null     float64
#  1   Monthly rent on typical property      92 non-null     float64
# dtypes: float64(2)
# memory usage: 2.2+ KB

# %%
index.describe()
# Out:
#        Monthly payment on a 2 bedroom house  Monthly rent on typical property
# count                             96.000000                         92.000000
# mean                            3274.909005                       2253.501859
# std                              893.989202                        290.924672
# min                             2205.609033                       1822.635793
# 25%                             2594.584617                       2001.194448
# 50%                             2789.675346                       2167.417340
# 75%                             4265.233957                       2557.749180
# max                             4877.543111                       2703.794360

# %%
index.isna().sum()
# Out:
# Monthly payment on a 2 bedroom house    0
# Monthly rent on typical property        4
# dtype: int64
